# %%
import pandas as pd
import json

# %%
# not for general consumption - need to hide this later
reso_token = '5ee86fc129f7535c4ef66f40d0edd57c'
dataset = 'test_sf'

# %%
df = pd.read_json('https://rets.io/api/v2/'+dataset+'/listings?access_token='+reso_token+'&limit=2&near=san%20francisco&radius=30')
df
# Out:
#                                               bundle  status  success  total
# 0  {'distanceFrom': 0.72129196493559, 'NewTaxesEx...     200     True  10000
# 1  {'distanceFrom': 0.723033867454363, 'NewTaxesE...     200     True  10000

# %%
df2 = df.bundle
df2
# Out:
# 0    {'distanceFrom': 0.72129196493559, 'NewTaxesEx...
# 1    {'distanceFrom': 0.723033867454363, 'NewTaxesE...
# Name: bundle, dtype: object

# %%
# write key information to dataframe
dict_for_df = {}
for key in df2.keys():
    dict_for_df[key] = df2[key]

# %%
listings = pd.DataFrame(dict_for_df)#,index = ['attribute1','attribute2'])
#listings = pd.DataFrame.transpose(listings)

# %%
listings
# Out:
#                                                                               0  \
# AboveGradeFinishedArea                                                     1229
# AboveGradeFinishedAreaSource                                              Agent
# AboveGradeFinishedAreaUnits                                         Square Feet
# AccessCode                                                                 2f53
# AccessibilityFeatures                                                      None
# AdditionalParcelsDescription                                               None
# AdditionalParcelsYN                                                       False
# AnchorsCoTenants              [Brekke, Huels and Kilback, Torphy-Hand, Tremb...
# Appliances                                               [Dishwasher, Disposal]
# ApprovalStatus                                                             None
# ArchitecturalStyle            [quis, voluptatem, dolores, ex, porro, ut, dol...
# AssociationAmenities                                                     [Pool]
# AssociationFee                                                              458
# AssociationFee2                                                             496
# AssociationFee2Frequency                                           Semi-Monthly
# AssociationFeeFrequency                                            Semi-Monthly
# AssociationFeeIncludes                                              [Utilities]
# AssociationName                                                             aut
# AssociationName2                                                  Adams-Pollich
# AssociationPhone                                                   813.021.8926
# AssociationPhone2                                                (903) 602-5900
# AssociationYN                                                             False
# AttachedGarageYN                                                           True
# AvailabilityDate                                       2018-06-24T12:59:48.276Z
# Basement                                                  [sit, natus, dolorem]
# BathroomsFull                                                                 9
# BathroomsHalf                                                                 3
# BathroomsOneQuarter                                                           1
# BathroomsPartial                                                              5
# BathroomsThreeQuarter                                                         1
# ...                                                                         ...
# VacancyAllowance                                                           None
# VacancyAllowanceRate                                                       None
# Vegetation                                                                 None
# VideosChangeTimestamp                                                      None
# VideosCount                                                                None
# View                                                          [View, Lake View]
# ViewYN                                                                     True
# VirtualTourURLBranded                                                      None
# VirtualTourURLUnbranded                                                    None
# WalkScore                                                                  None
# Walkscore                                                                    20
# WaterBodyName                                                              None
# WaterSewerExpense                                                          None
# WaterSource                   [Municipal, Irrigation District, Private Utility]
# WaterfrontFeatures                                                         None
# WaterfrontYN                                                              False
# WindowFeatures                                                             None
# WithdrawnDate                                                              None
# WoodedArea                                                                 None
# WorkmansCompensationExpense                                                None
# YearBuilt                                                                  1954
# YearBuiltDetails              Quaerat tenetur ullam repellendus. Nostrum vol...
# YearBuiltEffective                                                         None
# YearBuiltSource                                                        Estimate
# YearEstablished                                                            None
# YearsCurrentOwner                                                          None
# Zoning                                                                      R-1
# ZoningDescription                                                  Agricultural
# distanceFrom                                                           0.721292
# url                           https://rets.io/api/v2/test_sf/listings/P_5af6...
#
#                                                                               1
# AboveGradeFinishedArea                                                     6059
# AboveGradeFinishedAreaSource                                           Estimate
# AboveGradeFinishedAreaUnits                                               Acres
# AccessCode                                                                 m8js
# AccessibilityFeatures                                                      None
# AdditionalParcelsDescription                                                 []
# AdditionalParcelsYN                                                        True
# AnchorsCoTenants              [Goyette, Rolfson and Wisoky, Flatley, Schaefe...
# Appliances                              [Dishwasher, Disposal, Oven, Microwave]
# ApprovalStatus                                                             None
# ArchitecturalStyle                                                        [aut]
# AssociationAmenities                                                       None
# AssociationFee                                                              174
# AssociationFee2                                                             454
# AssociationFee2Frequency                                                 Weekly
# AssociationFeeFrequency                                           Semi-Annually
# AssociationFeeIncludes        [Earthquake Insurance, Insurance, Security, Ca...
# AssociationName                                                             eum
# AssociationName2                                                 Davis and Sons
# AssociationPhone                                                   331.158.8437
# AssociationPhone2                                                          None
# AssociationYN                                                             False
# AttachedGarageYN                                                          False
# AvailabilityDate                                       2018-07-02T09:32:03.847Z
# Basement                                                                   None
# BathroomsFull                                                                 5
# BathroomsHalf                                                                 3
# BathroomsOneQuarter                                                           2
# BathroomsPartial                                                              8
# BathroomsThreeQuarter                                                         3
# ...                                                                         ...
# VacancyAllowance                                                           None
# VacancyAllowanceRate                                                       None
# Vegetation                                                                 None
# VideosChangeTimestamp                                                      None
# VideosCount                                                                None
# View                                                          [View, Lake View]
# ViewYN                                                                     True
# VirtualTourURLBranded                                                      None
# VirtualTourURLUnbranded                                                    None
# WalkScore                                                                  None
# Walkscore                                                                    72
# WaterBodyName                                                              None
# WaterSewerExpense                                                          None
# WaterSource                                                         [Municipal]
# WaterfrontFeatures                                                         None
# WaterfrontYN                                                               True
# WindowFeatures                                                             None
# WithdrawnDate                                                              None
# WoodedArea                                                                 None
# WorkmansCompensationExpense                                                None
# YearBuilt                                                                  1968
# YearBuiltDetails              Veritatis ut tempore facere dolore officia opt...
# YearBuiltEffective                                                         None
# YearBuiltSource                                                        Assessor
# YearEstablished                                                            None
# YearsCurrentOwner                                                          None
# Zoning                                                                      C-1
# ZoningDescription                                                  Agricultural
# distanceFrom                                                           0.723034
# url                           https://rets.io/api/v2/test_sf/listings/P_5af6...
#
# [606 rows x 2 columns]

# %%
listings.to_csv('sample_list_sf.csv')

# %%
listings.describe
# Out:
# <bound method NDFrame.describe of                                                                               0  \
# AboveGradeFinishedArea                                                     1229
# AboveGradeFinishedAreaSource                                              Agent
# AboveGradeFinishedAreaUnits                                         Square Feet
# AccessCode                                                                 2f53
# AccessibilityFeatures                                                      None
# AdditionalParcelsDescription                                               None
# AdditionalParcelsYN                                                       False
# AnchorsCoTenants              [Brekke, Huels and Kilback, Torphy-Hand, Tremb...
# Appliances                                               [Dishwasher, Disposal]
# ApprovalStatus                                                             None
# ArchitecturalStyle            [quis, voluptatem, dolores, ex, porro, ut, dol...
# AssociationAmenities                                                     [Pool]
# AssociationFee                                                              458
# AssociationFee2                                                             496
# AssociationFee2Frequency                                           Semi-Monthly
# AssociationFeeFrequency                                            Semi-Monthly
# AssociationFeeIncludes                                              [Utilities]
# AssociationName                                                             aut
# AssociationName2                                                  Adams-Pollich
# AssociationPhone                                                   813.021.8926
# AssociationPhone2                                                (903) 602-5900
# AssociationYN                                                             False
# AttachedGarageYN                                                           True
# AvailabilityDate                                       2018-06-24T12:59:48.276Z
# Basement                                                  [sit, natus, dolorem]
# BathroomsFull                                                                 9
# BathroomsHalf                                                                 3
# BathroomsOneQuarter                                                           1
# BathroomsPartial                                                              5
# BathroomsThreeQuarter                                                         1
# ...                                                                         ...
# VacancyAllowance                                                           None
# VacancyAllowanceRate                                                       None
# Vegetation                                                                 None
# VideosChangeTimestamp                                                      None
# VideosCount                                                                None
# View                                                          [View, Lake View]
# ViewYN                                                                     True
# VirtualTourURLBranded                                                      None
# VirtualTourURLUnbranded                                                    None
# WalkScore                                                                  None
# Walkscore                                                                    20
# WaterBodyName                                                              None
# WaterSewerExpense                                                          None
# WaterSource                   [Municipal, Irrigation District, Private Utility]
# WaterfrontFeatures                                                         None
# WaterfrontYN                                                              False
# WindowFeatures                                                             None
# WithdrawnDate                                                              None
# WoodedArea                                                                 None
# WorkmansCompensationExpense                                                None
# YearBuilt                                                                  1954
# YearBuiltDetails              Quaerat tenetur ullam repellendus. Nostrum vol...
# YearBuiltEffective                                                         None
# YearBuiltSource                                                        Estimate
# YearEstablished                                                            None
# YearsCurrentOwner                                                          None
# Zoning                                                                      R-1
# ZoningDescription                                                  Agricultural
# distanceFrom                                                           0.721292
# url                           https://rets.io/api/v2/test_sf/listings/P_5af6...
#
#                                                                               1
# AboveGradeFinishedArea                                                     6059
# AboveGradeFinishedAreaSource                                           Estimate
# AboveGradeFinishedAreaUnits                                               Acres
# AccessCode                                                                 m8js
# AccessibilityFeatures                                                      None
# AdditionalParcelsDescription                                                 []
# AdditionalParcelsYN                                                        True
# AnchorsCoTenants              [Goyette, Rolfson and Wisoky, Flatley, Schaefe...
# Appliances                              [Dishwasher, Disposal, Oven, Microwave]
# ApprovalStatus                                                             None
# ArchitecturalStyle                                                        [aut]
# AssociationAmenities                                                       None
# AssociationFee                                                              174
# AssociationFee2                                                             454
# AssociationFee2Frequency                                                 Weekly
# AssociationFeeFrequency                                           Semi-Annually
# AssociationFeeIncludes        [Earthquake Insurance, Insurance, Security, Ca...
# AssociationName                                                             eum
# AssociationName2                                                 Davis and Sons
# AssociationPhone                                                   331.158.8437
# AssociationPhone2                                                          None
# AssociationYN                                                             False
# AttachedGarageYN                                                          False
# AvailabilityDate                                       2018-07-02T09:32:03.847Z
# Basement                                                                   None
# BathroomsFull                                                                 5
# BathroomsHalf                                                                 3
# BathroomsOneQuarter                                                           2
# BathroomsPartial                                                              8
# BathroomsThreeQuarter                                                         3
# ...                                                                         ...
# VacancyAllowance                                                           None
# VacancyAllowanceRate                                                       None
# Vegetation                                                                 None
# VideosChangeTimestamp                                                      None
# VideosCount                                                                None
# View                                                          [View, Lake View]
# ViewYN                                                                     True
# VirtualTourURLBranded                                                      None
# VirtualTourURLUnbranded                                                    None
# WalkScore                                                                  None
# Walkscore                                                                    72
# WaterBodyName                                                              None
# WaterSewerExpense                                                          None
# WaterSource                                                         [Municipal]
# WaterfrontFeatures                                                         None
# WaterfrontYN                                                               True
# WindowFeatures                                                             None
# WithdrawnDate                                                              None
# WoodedArea                                                                 None
# WorkmansCompensationExpense                                                None
# YearBuilt                                                                  1968
# YearBuiltDetails              Veritatis ut tempore facere dolore officia opt...
# YearBuiltEffective                                                         None
# YearBuiltSource                                                        Assessor
# YearEstablished                                                            None
# YearsCurrentOwner                                                          None
# Zoning                                                                      C-1
# ZoningDescription                                                  Agricultural
# distanceFrom                                                           0.723034
# url                           https://rets.io/api/v2/test_sf/listings/P_5af6...
#
# [606 rows x 2 columns]>

# %%
lt = pd.DataFrame.transpose(listings)

# %%
lt
# Out:
#   AboveGradeFinishedArea AboveGradeFinishedAreaSource  \
# 0                   1229                        Agent
# 1                   6059                     Estimate
#
#   AboveGradeFinishedAreaUnits AccessCode AccessibilityFeatures  \
# 0                 Square Feet       2f53                  None
# 1                       Acres       m8js                  None
#
#   AdditionalParcelsDescription AdditionalParcelsYN  \
# 0                         None               False
# 1                           []                True
#
#                                     AnchorsCoTenants  \
# 0  [Brekke, Huels and Kilback, Torphy-Hand, Tremb...
# 1  [Goyette, Rolfson and Wisoky, Flatley, Schaefe...
#
#                                 Appliances ApprovalStatus  \
# 0                   [Dishwasher, Disposal]           None
# 1  [Dishwasher, Disposal, Oven, Microwave]           None
#
#                          ...                         YearBuilt  \
# 0                        ...                              1954
# 1                        ...                              1968
#
#                                     YearBuiltDetails YearBuiltEffective  \
# 0  Quaerat tenetur ullam repellendus. Nostrum vol...               None
# 1  Veritatis ut tempore facere dolore officia opt...               None
#
#   YearBuiltSource YearEstablished YearsCurrentOwner Zoning ZoningDescription  \
# 0        Estimate            None              None    R-1      Agricultural
# 1        Assessor            None              None    C-1      Agricultural
#
#   distanceFrom                                                url
# 0     0.721292  https://rets.io/api/v2/test_sf/listings/P_5af6...
# 1     0.723034  https://rets.io/api/v2/test_sf/listings/P_5af6...
#
# [2 rows x 606 columns]
